# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([226, 226, 226, 226, 226, 339, 339, 339, 339, 339, 
     452, 452, 452, 452, 452, 565, 565, 565, 565, 565])
y = np.array([850, 950, 1057, 1172, 1294, 963, 1063, 1170, 1285, 1407, 
     1076, 1176, 1283, 1398, 1520, 1189, 1289, 1396, 1511, 1633])
z = np.array([0.002, 0.0024, 0.0026, 0.0026, 0.0032, 0.0017, 0.0021, 0.0021, 0.0022, 
     0.0023, 0.0019, 0.0021, 0.0022, 0.0027, 0.0027, 0.0022, 0.0024, 0.0025, 
     0.003, 0.003])

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('Vertex')
ax.set_ylabel('Edges')
ax.set_zlabel('Time')

ax.plot_surface(x, y, z, alpha=0.2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-b7286b255c90> in <module>
#       7 ax.set_zlabel('Time')
#       8
# ----> 9 ax.plot_surface(x, y, z, alpha=0.2)
#      10
#      11 plt.show()
#
# C:\Program Files\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1604
#    1605         if Z.ndim != 2:
# -> 1606             raise ValueError("Argument Z must be 2-dimensional.")
#    1607         if np.any(np.isnan(Z)):
#    1608             cbook._warn_external(
#
# ValueError: Argument Z must be 2-dimensional.
