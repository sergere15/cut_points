# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import numpy as np

# %%
x = np.array([226, 226, 226, 226, 226, 339, 339, 339, 339, 339, 
     452, 452, 452, 452, 452, 565, 565, 565, 565, 565])
y = np.array([850, 950, 1057, 1172, 1294, 963, 1063, 1170, 1285, 1407, 
     1076, 1176, 1283, 1398, 1520, 1189, 1289, 1396, 1511, 1633])
z = np.array([0.002, 0.0024, 0.0026, 0.0026, 0.0032, 0.0017, 0.0021, 0.0021, 0.0022, 
     0.0023, 0.0019, 0.0021, 0.0022, 0.0027, 0.0027, 0.0022, 0.0024, 0.0025, 
     0.003, 0.003])

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('Vertex')
ax.set_ylabel('Edges')
ax.set_zlabel('Time')

plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('Vertex')
ax.set_ylabel('Edges')
ax.set_zlabel('Time')

for i in range (0, 20, 5):
    ax.plot(x[i:i+5], y[i:i+5], z[i:i+5], alpha=0.2)
plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.scatter(x, z, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('Vertex')
ax.set_ylabel('Time')

plt.ylim(0, 0.005)
plt.yticks(np.arange(0, 0.005, 0.0005))

plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.scatter(x, z, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('Vertex')
ax.set_ylabel('Time')

plt.ylim(0, 0.005)
plt.yticks(np.arange(0, 0.005, 0.0005))

ax.plot(x, z, alpha=0.4)

plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.scatter(y, z, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('Edges')
ax.set_ylabel('Time')

plt.ylim(0, 0.005)
plt.yticks(np.arange(0, 0.005, 0.0005))

plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.scatter(y, z, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('Edges')
ax.set_ylabel('Time')

plt.ylim(0, 0.005)
plt.yticks(np.arange(0, 0.005, 0.0005))

for i in range (0, 20, 5):
    ax.plot(y[i:i+5], z[i:i+5], alpha=0.3)
plt.show()
